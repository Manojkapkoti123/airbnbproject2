# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojkapkoti123/airbnbproject2/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# contributor- Manoj Singh Kapkoti

# %% [markdown]
# In this project, we'll be working with the AirBnb Bookings dataset where we'll first start with getting to know what Airbnb is. AirBnb is an online platform where users can find homes or rooms to rent for a day or week. Hosts list their property on Airbnb, the prices, availability and other data that is necessary to inform the users before they decide to rent that particular property. Basically, they provide a platform and a network of people that include hosts and users worldwide for best travel experiences or finding places to rent.
#
# Now for knowing the dataset, we'll be starting with getting to know the data and describe it, check for variables and their correlations and how they're related to each other. We'll work with the null values, the values that are odd which are statistically termed as 'Outliers'. Also, finding out the most popular places, their prices and what the users prefer most when booking on Airbnb.
#
# We'll also be visualising all our findings and give it a visual representation for more clarity in the information

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
#  **Problem Statement**

# %% [markdown]
# The Airbnb dataset contains a wealth of information about various properties listed on Airbnb's platform, including details about the listing's price, location, amenities, host, and user reviews. The goal of this project is to perform a detailed analysis of Airbnb listings to uncover insights related to pricing, location preferences, and overall listing quality.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# he primary business objective of Airbnb is to enhance the overall user experience for both hosts and guests, while optimizing the platform’s operational efficiency and profitability. The goal is to ensure that Airbnb remains the go-to platform for people seeking unique, affordable, and trusted accommodations worldwide.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
filepath='/content/drive/MyDrive/module2/Airbnb NYC 2019.csv'
df=pd.read_csv(filepath)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.columns.value_counts()
# Out:
# id                                1
# name                              1
# host_id                           1
# host_name                         1
# neighbourhood_group               1
# neighbourhood                     1
# latitude                          1
# longitude                         1
# room_type                         1
# price                             1
# minimum_nights                    1
# number_of_reviews                 1
# last_review                       1
# reviews_per_month                 1
# calculated_host_listings_count    1
# availability_365                  1
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# filling the missing value
df.fillna(0, inplace = True)

# %%
# Visualizing the missing values
import seaborn as sns
sns.heatmap(df.isnull(),cbar= False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ur dataset has 48895 data and 16 columns. Understanding about the columns we've got here.
#
# id : a unique id identifying an airbnb lisitng
# name : name representating the accomodation
# host_id : a unique id identifying an airbnb host
# host_name : name under whom host is registered
# neighbourhood_group : a group of area
# beighbourhood : area falls under neighbourhood_group
# latitude : coordinate of listing
# longitude : coordinate of listing
# room_type : type to categorize listing rooms
# price : price of listing
# minimum_nights : the minimum nights required to stay in a single visit
# number_of_reviews : total count of reviews given by visitors
# last_review : date of last review given
# reviews_per_month : rate of reviews given per month
# calculated_host_listings_count : total no of listing registered under the host
# availability_365 : the number of days for which a host is available in a year.
# Latitude and longitude has represented a co-ordinate, neighbourhood_group, neighbourhood and room_type are categorical type columns. Last_review is a column of date type, we can convert it as required.
# There are 4 columns containing null values which are name, host_name and last_reviews, reviews_per_month (if a listing has never received a review, its possible and valid). So we just fillna(0) to those null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe
# Out:
# <bound method NDFrame.describe of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df[df['host_name']=='Susan']
# Out:
#              id                                               name    host_id  \
# 533      195123                         Cheerful, comfortable room     940724
# 566      212109     2-bedroom share in heart of Greenwich Village!     666271
# 948      364785             Sunny large private room in Park Slope    1842714
# 1687     765315                Bed & Bathroom in Williamsburg Loft    4034995
# 2281    1095106                  Greenpoint - with your own space!    6016424
# 3223    1925224                    Beautiful, large, charming spot    9946315
# 3229    1929186                 Modern Bright Loft in Clinton Hill    9990552
# 3390    2030736                                             Room B   10384906
# 3395    2036105                                    Private room  D   10384906
# 3558    2124910                                     Private Room E   10384906
# 4096    2632699                               Budge private room F   10384906
# ...

# %%
df[df['name'] == df['host_name']] #checking for correlations
# Out:
#              id            name    host_id       host_name  \
# 9473    7264659         Olivier    6994503         Olivier
# 10682   8212051           Monty   43302952           Monty
# 16422  13186374            Sean   35143476            Sean
# 23996  19348168             Cyn   74033595             Cyn
# 24152  19456810  Hillside Hotel  134184451  Hillside Hotel
# 24607  19785737  Hillside Hotel  134184451  Hillside Hotel
# 26734  21231543  Hillside Hotel  134184451  Hillside Hotel
# 26752  21243952  Hillside Hotel  134184451  Hillside Hotel
# 26753  21244035  Hillside Hotel  134184451  Hillside Hotel
# 26889  21311903  Hillside Hotel  134184451  Hillside Hotel
# 26891  21312075  Hillside Hotel  134184451  Hillside Hotel
# 26892  21312191  Hillside Hotel  134184451  Hillside Hotel
# 26893  21312225  Hillside Hotel  134184451  Hillside Hotel
# 26894  21312283  Hillside Hotel  134184451  Hillside Hotel
# 26895  21312330  Hillside Hotel  134184451  Hillside Hotel
# ...

# %%
df.loc[(df['neighbourhood_group'] == 'Brooklyn') & (df['name'] == 'Sean')]
# Out:
#              id  name   host_id host_name neighbourhood_group  \
# 16422  13186374  Sean  35143476      Sean            Brooklyn
#
#          neighbourhood  latitude  longitude        room_type  price  \
# 16422  Windsor Terrace  40.65182  -73.98043  Entire home/apt    400
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 16422               7                  0           0                0.0
#
#        calculated_host_listings_count  availability_365
# 16422                               1                 0

# %% [markdown]
# A property name will have one host_name hosted by that same individual but a particular host_name can have multiple properties in a area.
# So, host_name is a categorical variable here. Also neighbourhood_group,neighbourhood and room_type fall into this category.
# While Id, latitude, longitude, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365 are numerical variables
# Furthermore, A host can have multiple properties in a neighbourhood group with different host-ids but a host with a particular property/listing in a particular neighbourhood of a neighbourhood group have a same host-id (in some cases some hosts gave different ids for each listing/property in neighborhood)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df[df['price'] == 0]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
len(df[df['price'] == 0])
# Out:
# 11

# %%
df['host_name'].value_counts()[:3] #Michael has the most number of listings here.
# Out:
# host_name
# Michael         417
# David           403
# Sonder (NYC)    327
# Name: count, dtype: int64

# %%
df['price'].max()
# Out:
# 10000

# %%
df['price'].idxmax()
# Out:
# 9151

# %%
df.iloc[9151]
# Out:
# id                                                            7003697
# name                              Furnished room in Astoria apartment
# host_id                                                      20582832
# host_name                                                    Kathrine
# neighbourhood_group                                            Queens
# neighbourhood                                                 Astoria
# latitude                                                      40.7681
# longitude                                                   -73.91651
# room_type                                                Private room
# price                                                           10000
# minimum_nights                                                    100
# number_of_reviews                                                   2
# last_review                                                2016-02-13
# ...

# %%
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
df['minimum_nights'].max()
# Out:
# 1250

# %%
df['reviews_per_month'].idxmax()
# Out:
# 42075

# %%
df.iloc[42075]
# Out:
# id                                                                         32678719
# name                              Enjoy great views of the City in our Deluxe Room!
# host_id                                                                   244361589
# host_name                                                                   Row NYC
# neighbourhood_group                                                       Manhattan
# neighbourhood                                                      Theater District
# latitude                                                                   40.75918
# longitude                                                                 -73.98801
# room_type                                                              Private room
# price                                                                           100
# minimum_nights                                                                    1
# ...

# %%
len(df[df['availability_365'] == 0])
# Out:
# 17533

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
(df[df['last_review']==0])
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?
# Through the manipulations and trying out a few things, we get to know that there exist listings which are listed for 0 price, the most number of listings are in Manhattan while the most number of listings that a host has is Michael with 417 listings in multiple places. The maximum price in this dataset is 10000 whose host is katherine, listed in Queens, Astoria.
# Manhattan being the most preferred neighbourhood by hosts. The maximum number of nights a guest can stay at a place according to this dataset is 3.4 years while there are listings where the number is 0 making it unavailable.
#
# The maximum number of reviews a host has is 58.5 in manhattan. There are 17533 listings in this dataset where the minimum number of nights is 0 making it unavailable. Most of these listings are an entire home/apartments being followed by private rooms and considerably low number of shared rooms. This indicates that users prefer entire home/apartment and private rooms the most.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#distplot
sns.set(rc={"figure.figsize": (20, 6)})
sns.distplot(df['price'],hist=True)
# Out:
# <ipython-input-147-cfea3a34fbce>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],hist=True)
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This graph shows the range of distribution and where it is has the highest density probability. It only needs one variable and it estimates the y-axis giving a visual representation of a graph made with only one variable provided. Here, price is given.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# his graph tells us that it has a positive skewness and it does not deviate much from normal distribution. This graph shows that the probability density is the highest around the prices between 0 to 2000. It shows that most hosts prefer setting their prices in this range.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The skew and kurtosis came out very large. Since the skewness has value>1 it is highly skewed. The kurtosis is also very high which shows that there are outliers in the dataset.Answer Here

# %% [markdown]
# #### Chart - 2

# %%
from os import posix_fallocate
# Chart - 2 visualization code
#scatter plot
sns.scatterplot(x=df['price'],y=df['minimum_nights'])
# Out:
# <Axes: xlabel='price', ylabel='minimum_nights'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot is used for finding out the corelation between two variables. It can help to determine any kind of relation between your two variables. So here we try to find any corelation between minimum nights and the prices of the listed propertiesAnswer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph shows there are many outliers here too. The plots are all mostly clustered around 0 to 2000 prices with minimum nights between 0 to 200. A few of them have minimum nights more than 0 but the price seems to be 0 too which indicates anomalies in the data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# boxplot
plt.figure(figsize=(8,3))
df.boxplot(column = ['price'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plot will show where the median stands and help understand the amount of outliers in the dataset with points. It will show the trend of prices in different quartiles/parts.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Way too many outliers. The boxes are heavily compressed near the lowest values which is close to 0. The extremely short box indicates that most owners follow the price trends keeping the prices similar to the other, hence, resulting in a compressed box with values focused near 0.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#bar graph
plt.figure(figsize=(5,2))
sns.barplot(x=df['neighbourhood_group'],y=df['price'],color='red')
plt.xlabel('neighbourhood_group')
plt.ylabel('price')
plt.title('neighbourhood_group vs price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are very easy to read and gives the visual representation of quantity as compared to other variables in the column.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As per the graph, these are the top C with maximum number of manhattan, broklyn and island are similar , bronx is the lowest neighbourhood

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#count plot
plt.figure(figsize=(5,2))
sns.countplot(x=df['room_type'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot shows the number of observations in each category, which makes it simple to interpret.
# It uses bars to display the count of data points in each category, so you can quickly see which categories are most or least frequent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire home/appartment was the highest and shared room was less in report.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Negative Impact: A high rate of dissatisfaction can damage AirMBM’s reputation, leading to lower customer retention, negative word-of-mouth, and ultimately lost revenue. Negative customer reviews can also impact brand perception and reduce new customer acquisition.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code Scatterplot
plt.figure(figsize=(10,4))
sns.scatterplot(x=df['minimum_nights'],y=df['price'])
plt.title('minimum_nights vs price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a powerful and commonly used data visualization tool in statistics and data analysis. It is typically used to display the relationship between two continuous variables, showing how one variable is affected by the other, and whether any correlation exists between them. Here are some key reasons why scatter plots are used:

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a clear positive correlation between minimum_nights and price.
#
# *	This aligns with the common understanding that higher price often indicates more minimum_nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# there isn't any negative growth

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
 #Distplot (reviews_per_month)
plt.figure(figsize=(6,3))
sns.distplot(df['reviews_per_month'])
plt.show()
# Out:
# <ipython-input-153-4d56cd93cf07>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['reviews_per_month'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  It combines several key statistical visualizations into one plot, making it easier to understand the underlying distribution of data and to detect patterns, trends, or anomalies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This distribution looks positively skewed on the right with long tails that show there are outliers present. Also, the monthly reviews is between 0 to 10 with the highest review in the range being 60.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code strip plot
f,ax = plt.subplots(figsize=(20,8))
ax= sns.stripplot(x='room_type', y='reviews_per_month', hue='neighbourhood_group', dodge=True, data=df ,palette='pastel')
ax.set_title('Most Reviewed room_types in each Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Most Reviewed room_types in each Neighbourhood Groups')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Manhattan having the most number of reviews per month being above 50 which are private rooms followed by Queens. It seems that private rooms have a higher review rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan & Queens got the most no of reviews for Entire home/apt room type.
#
# There were less reviews recieved from shared rooms as compared to other room types and it was from Staten Island followed by Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code barplot
plt.figure(figsize=(5,2))
sns.barplot(x=df['neighbourhood_group'],y=df['calculated_host_listings_count'],color='red')
plt.xlabel('neighbourhood_group')
plt.ylabel('calculated_host_listings_count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# between a cat and 1 numerical data and Bar plots are useful for comparing the frequency, count, or any other aggregated measure across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# calculated_host_listings_count is highest in manhattan and 2nd highest in middle one and rest 3 have same level

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code count plot
sns.countplot(df['neighbourhood_group'], palette='plasma')
fig = plt.gcf()
fig.set_size_inches(6,4)
plt.title("Neighbourhood Group")
plt.show()
# Out:
# <ipython-input-171-6e607f079d7c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df['neighbourhood_group'], palette='plasma')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is very useful when you want to quickly understand how often each category appears in your dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhatten and Brooklyn are the most resulted neighbour groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#Map of Neighbourhood group
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, color='purple', bins=50)
plt.title('Distribution of Airbnb Listing Prices')
plt.xlabel('Price ($)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Histogram helps in visualizing the frequency of price ranges.
# Kernel Density Estimate (KDE) gives a smoothed curve of the distribution

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='neighbourhood', y='price', data=df, palette='Set1')
plt.title('Price Distribution by Neighbourhood')
plt.xlabel('Neighbourhood')
plt.ylabel('Price ($)')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-183-04a3b6d958f2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='neighbourhood', y='price', data=df, palette='Set1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplots give a summary of the distribution of the price for each room type, including the median, quartiles, and potential outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code bar plot  op 10 Neighbourhoods by Listing Count
plt.figure(figsize=(8,4))
top_neighbourhoods = df['neighbourhood'].value_counts().nlargest(10)
sns.barplot(x=top_neighbourhoods.index, y=top_neighbourhoods.values, palette='Blues_d')
plt.title('Top 10 Neighbourhoods by Listing Count')
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-187-222e06823df8>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_neighbourhoods.index, y=top_neighbourhoods.values, palette='Blues_d')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Barplot is used here to show the count of listings in the top 10 neighborhoods.
# value_counts() helps in counting occurrences of each neighborhood.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# williamrburg is the highest and  midtown has the lowest neighbourhood and upper-west-side and hell's kitchen have equal number of neighbour which is apprxomately 1900

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# no impact on negative growth as all have greater than 1300 neighbourhood

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
data.corr()
# Out:
#                                       id  latitude  longitude  minimum_nights  \
# id                              1.000000 -0.003125   0.090908       -0.013224
# latitude                       -0.003125  1.000000   0.084788        0.024869
# longitude                       0.090908  0.084788   1.000000       -0.062747
# minimum_nights                 -0.013224  0.024869  -0.062747        1.000000
# number_of_reviews              -0.319760 -0.015389   0.059094       -0.080116
# reviews_per_month               0.180221 -0.018758   0.138516       -0.124905
# calculated_host_listings_count  0.133272  0.019517  -0.114713        0.127960
# availability_365                0.085468 -0.010983   0.082731        0.144303
#
#                                 number_of_reviews  reviews_per_month  \
# id                                      -0.319760           0.180221
# latitude                                -0.015389          -0.018758
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It helps understand the correlation between two entites so here we're looking at multiple correlations narrated below

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Statistical term used find relationship between 2 numerical varibales.
#
# * corr is 1 : strong relationship
# * corr is 0 : No relationship
# * corr is -1 : Negative relationship

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
data= df.select_dtypes(include=['int64','float64'])
data.drop(['host_id','price'],inplace=True ,axis=1)
sns.pairplot(data)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Detect extreme values or outliers in features like price or reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# One of the key questions in an Airbnb dataset is often about the relationship between price and other continuous variables such as number of reviews, availability, room size, and ratings. A pair plot helps you visualize how price correlates with these other features.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve its business objectives, Airbnb should use a combination of data analysis, targeted marketing, operational improvements, and customer insights. By leveraging detailed market segmentation, dynamic pricing, personalization, and sustainability practices, Airbnb can improve both host and guest experiences while also increasing revenue and market share.
#
# These strategies should be regularly evaluated using data-driven insights to ensure that Airbnb stays competitive, scalable, and aligned with customer needs

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After the above operations, we can conclude that:
#
# Manhattan is the most expensive place in NYC
# Most users don't prefer shared rooms. There are considerably more entire home/apt and private rooms as compared to shared.
# The location of the property also has an affect on the property listing's price.
# Most of the cheaper options like in Staten Islands and Bronx are available throughout the year.
# With more variables like tax_rate, amentities and so on, we can make a deeper dive in the how users decide to rent and the trend of availability, available nights and prices.Write the conclusion here.
# Having more options in the dataset like schools, hospitals, grocery marts, convenience stores, etc near the property would've helped decide the trend of prices in a more detailed way since they might have high relation with the prices listed.
# We could've also used time series to find which seasons, time of the year the properties would be the busiest.
# We even used data charts for a better understanding and a rough idea of how the data might work with other variables.
# Here, we conclude our analysis.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
